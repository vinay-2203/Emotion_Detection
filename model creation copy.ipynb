# %% [markdown]
# # #Emotion_Detection

# %%
from matplotlib import pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization ,Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint,ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image
import tensorflow as tf
print("tensorflow version :",tf.__version__)
# Out:
# tensorflow version : 2.12.0

# %% [markdown]
# # Exploring Dataset

# %%
images = glob("train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %% [markdown]
# # **Preparing data for training

# %%
img_size = 48
batch_size = 64
datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory("train/",
                                                    target_size = (img_size,img_size),
                                                    color_mode = "grayscale",
                                                    batch_size = batch_size,
                                                    class_mode = "categorical",
                                                    shuffle = True)

datagen_validation = ImageDataGenerator()
validation_generator = datagen_train.flow_from_directory("test/",
                                                    target_size = (img_size,img_size),
                                                    color_mode = "grayscale",
                                                    batch_size = batch_size,
                                                    class_mode = "categorical",
                                                    shuffle = True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # Defining Model

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters = filters,kernel_size = kernel_size,padding = "same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size = (2,2))(x)
    x = Dropout(0.25)(x)
    
    return (x)

# %%
def Dense_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)
    
    return (x)

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs,32,(3,3))
    conv_2 = Convolution(inputs,64,(5,5))
    conv_3 = Convolution(inputs,128,(3,3))
    
    flatten = Flatten()(conv_3)
    
    dense_1 = Dense_f(flatten,256)
    
    output = Dense(7,activation = "softmax")(dense_1)
    model = Model(inputs = [inputs], outputs = [output])
    model.compile(loss = ['categorical_crossentropy'], optimizer = 'adam', metrics = ['accuracy'])
    
    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       1280
#
#  batch_normalization_2 (Batc  (None, 48, 48, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 48, 48, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 24, 24, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 24, 24, 128)       0
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 256)               18874624
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 18,879,239
# Trainable params: 18,878,471
# Non-trainable params: 768
# _________________________________________________________________

# %% [markdown]
# # Initializing the models

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint("model_wieghts.h5", monitor = 'val_accuracy', save_weights_only = True, mode = 'max', verbose = 1)
callbacks = [checkpoint]

# %% [markdown]
# # Training Model

# %% [markdown]
# **The next cell take time to complete the process**

# %%
history = model.fit(
x = train_generator,
steps_per_epoch = steps_per_epoch,
epochs = epochs,
validation_data = validation_generator,
validation_steps = validation_steps,
callbacks = callbacks)
# Out:
# Epoch 1/15
# 2024-06-26 10:31:09.353757: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 448/448 [==============================] - ETA: 0s - loss: 1.6433 - accuracy: 0.3752
# Epoch 1: saving model to model_wieghts.h5
# 448/448 [==============================] - 70s 155ms/step - loss: 1.6433 - accuracy: 0.3752 - val_loss: 1.5206 - val_accuracy: 0.4226
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3556 - accuracy: 0.4861
# Epoch 2: saving model to model_wieghts.h5
# 448/448 [==============================] - 74s 166ms/step - loss: 1.3556 - accuracy: 0.4861 - val_loss: 1.5122 - val_accuracy: 0.4255
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1944 - accuracy: 0.5514
# Epoch 3: saving model to model_wieghts.h5
# 448/448 [==============================] - 76s 169ms/step - loss: 1.1944 - accuracy: 0.5514 - val_loss: 1.5002 - val_accuracy: 0.4229
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0637 - accuracy: 0.6054
# Epoch 4: saving model to model_wieghts.h5
# 448/448 [==============================] - 81s 180ms/step - loss: 1.0637 - accuracy: 0.6054 - val_loss: 1.6339 - val_accuracy: 0.4249
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9369 - accuracy: 0.6605
# Epoch 5: saving model to model_wieghts.h5
# 448/448 [==============================] - 98s 220ms/step - loss: 0.9369 - accuracy: 0.6605 - val_loss: 1.5894 - val_accuracy: 0.4443
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8195 - accuracy: 0.7045
# Epoch 6: saving model to model_wieghts.h5
# 448/448 [==============================] - 111s 248ms/step - loss: 0.8195 - accuracy: 0.7045 - val_loss: 1.6295 - val_accuracy: 0.4223
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 0.7047 - accuracy: 0.7491
# Epoch 7: saving model to model_wieghts.h5
# 448/448 [==============================] - 106s 237ms/step - loss: 0.7047 - accuracy: 0.7491 - val_loss: 1.7046 - val_accuracy: 0.4367
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5995 - accuracy: 0.7885
# Epoch 8: saving model to model_wieghts.h5
# 448/448 [==============================] - 116s 260ms/step - loss: 0.5995 - accuracy: 0.7885 - val_loss: 1.6443 - val_accuracy: 0.4650
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5178 - accuracy: 0.8184
# Epoch 9: saving model to model_wieghts.h5
# 448/448 [==============================] - 162s 361ms/step - loss: 0.5178 - accuracy: 0.8184 - val_loss: 1.6237 - val_accuracy: 0.4682
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.4460 - accuracy: 0.8461
# Epoch 10: saving model to model_wieghts.h5
# 448/448 [==============================] - 163s 365ms/step - loss: 0.4460 - accuracy: 0.8461 - val_loss: 1.7631 - val_accuracy: 0.4657
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3879 - accuracy: 0.8674
# Epoch 11: saving model to model_wieghts.h5
# 448/448 [==============================] - 162s 361ms/step - loss: 0.3879 - accuracy: 0.8674 - val_loss: 1.7788 - val_accuracy: 0.4870
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3397 - accuracy: 0.8854
# Epoch 12: saving model to model_wieghts.h5
# 448/448 [==============================] - 141s 315ms/step - loss: 0.3397 - accuracy: 0.8854 - val_loss: 1.8422 - val_accuracy: 0.4784
# Epoch 13/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3086 - accuracy: 0.8959
# Epoch 13: saving model to model_wieghts.h5
# 448/448 [==============================] - 125s 278ms/step - loss: 0.3086 - accuracy: 0.8959 - val_loss: 1.7968 - val_accuracy: 0.5046
# Epoch 14/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2702 - accuracy: 0.9093
# Epoch 14: saving model to model_wieghts.h5
# 448/448 [==============================] - 125s 279ms/step - loss: 0.2702 - accuracy: 0.9093 - val_loss: 1.9899 - val_accuracy: 0.4828
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2432 - accuracy: 0.9210
# Epoch 15: saving model to model_wieghts.h5
# 448/448 [==============================] - 117s 261ms/step - loss: 0.2432 - accuracy: 0.9210 - val_loss: 2.0208 - val_accuracy: 0.4777

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 [==============================] - 4s 32ms/step - loss: 2.0247 - accuracy: 0.4772
# [2.024697780609131, 0.47715240716934204]

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top = 1.0,bottom=0.0,right = 0.95,left = 0.0,hspace=0.25,wspace = 0.35)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top = 1.0,bottom=0.0,right = 0.95,left = 0.0,hspace=0.25,wspace = 0.35)

# %% [markdown]
# # Saving Model

# %%
model_json = model.to_json()
with open("model_a.json","w") as json_file:
    json_file.write(model_json)
